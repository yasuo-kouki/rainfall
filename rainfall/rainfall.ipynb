# %%
import pandas as pd
import numpy as np

# %% [markdown]
# ### データの読み込み

# %%
train = pd.read_csv('data/train.csv')
test = pd.read_csv('data/test.csv')

# %%
train.head()
# Out:
#    id  day  pressure  maxtemp  temparature  mintemp  dewpoint  humidity  \
# 0   0    1    1017.4     21.2         20.6     19.9      19.4      87.0
# 1   1    2    1019.5     16.2         16.9     15.8      15.4      95.0
# 2   2    3    1024.1     19.4         16.1     14.6       9.3      75.0
# 3   3    4    1013.4     18.1         17.8     16.9      16.8      95.0
# 4   4    5    1021.8     21.3         18.4     15.2       9.6      52.0
#
#    cloud  sunshine  winddirection  windspeed  rainfall
# 0   88.0       1.1           60.0       17.2         1
# 1   91.0       0.0           50.0       21.9         1
# 2   47.0       8.3           70.0       18.1         1
# 3   95.0       0.0           60.0       35.6         1
# 4   45.0       3.6           40.0       24.8         0

# %%
test.head()
# Out:
#      id  day  pressure  maxtemp  temparature  mintemp  dewpoint  humidity  \
# 0  2190    1    1019.5     17.5         15.8     12.7      14.9      96.0
# 1  2191    2    1016.5     17.5         16.5     15.8      15.1      97.0
# 2  2192    3    1023.9     11.2         10.4      9.4       8.9      86.0
# 3  2193    4    1022.9     20.6         17.3     15.2       9.5      75.0
# 4  2194    5    1022.2     16.1         13.8      6.4       4.3      68.0
#
#    cloud  sunshine  winddirection  windspeed
# 0   99.0       0.0           50.0       24.3
# 1   99.0       0.0           50.0       35.3
# 2   96.0       0.0           40.0       16.9
# 3   45.0       7.1           20.0       50.6
# 4   49.0       9.2           20.0       19.4

# %% [markdown]
# ### 学習データを特徴量と目的変数に分ける

# %%
train_x = train.drop(['rainfall'],axis=1)
train_y = train['rainfall']

test_x = test.copy()

# %% [markdown]
# ### データを調べる

# %% [markdown]
# データの方の確認

# %%
train_x.dtypes
#objectの場合型が混在する
# Out:
# id                 int64
# day                int64
# pressure         float64
# maxtemp          float64
# temparature      float64
# mintemp          float64
# dewpoint         float64
# humidity         float64
# cloud            float64
# sunshine         float64
# winddirection    float64
# windspeed        float64
# dtype: object

# %%
train_x.isnull().sum()
# Out:
# id               0
# day              0
# pressure         0
# maxtemp          0
# temparature      0
# mintemp          0
# dewpoint         0
# humidity         0
# cloud            0
# sunshine         0
# winddirection    0
# windspeed        0
# dtype: int64

# %%
print(train_x["day"].describe())
# Out:
# count    2190.000000
# mean      179.948402
# std       105.203592
# min         1.000000
# 25%        89.000000
# 50%       178.500000
# 75%       270.000000
# max       365.000000
# Name: day, dtype: float64

# %% [markdown]
# ヒストグラムを分布で確認

# %%
import matplotlib.pyplot as plt

train_x.hist(figsize=(12,8),bins=30)
plt.show()

# %% [markdown]
# ### 変数の削除をする

# %%
# idの列は削除する
train_x = train_x.drop(['id'],axis=1)
test_x = test_x.drop(['id'],axis=1)

# %% [markdown]
# ## 特徴量の作成

# %% [markdown]
# ### 月の作成

# %%
# 1月1日を基準に日付に変換
train_x['date'] = pd.to_datetime('2024-01-01') + pd.to_timedelta(train_x['day']-1,unit='D')
test_x['date'] = pd.to_datetime('2024-01-01') + pd.to_timedelta(test_x['day']-1,unit='D')

# 月の数値を習得
train_x['month'] = train_x['date'].dt.month
test_x['month'] = test_x['date'].dt.month

#月の周期変換
train_x['month_sin'] = np.sin(2 * np.pi * train_x['month']/12)
train_x['month_cos'] = np.cos(2 * np.pi * train_x['month']/12)

test_x['month_sin'] = np.sin(2 * np.pi * test_x['month']/12)
test_x['month_cos'] = np.cos(2 * np.pi * test_x['month']/12)

# 不要な列を削除
train_x.drop(columns=['date'], inplace=True)
test_x.drop(columns=['date'], inplace=True)

print(train_x[['day','month','month_sin','month_cos']].head())
# Out:
#    day  month  month_sin  month_cos
# 0    1      1        0.5   0.866025
# 1    2      1        0.5   0.866025
# 2    3      1        0.5   0.866025
# 3    4      1        0.5   0.866025
# 4    5      1        0.5   0.866025

# %% [markdown]
# ### 周期的な日の変換

# %%
train_x['day_sin'] = np.sin(2 * np.pi * train_x['day'] / 365)
train_x['day_cos'] = np.cos(2 * np.pi * train_x['day'] / 365)

test_x['day_sin'] = np.sin(2 * np.pi * test_x['day'] / 365)
test_x['day_cos'] = np.cos(2 * np.pi * test_x['day'] / 365)
print(train_x[['day','day_sin']].head())
# Out:
#    day   day_sin
# 0    1  0.017213
# 1    2  0.034422
# 2    3  0.051620
# 3    4  0.068802
# 4    5  0.085965

# %% [markdown]
# ### 気温をmax<minとなっている列を欠損値とする

# %%
print(train_x[~(train_x['maxtemp'] > train_x['mintemp'])])
train_x.loc[train_x['maxtemp'] <= train_x['mintemp'], 'maxtemp'] = np.nan
test_x.loc[test_x['maxtemp'] <= test_x['mintemp'], 'maxtemp'] = np.nan
# Out:
#       day  pressure  maxtemp  temparature  mintemp  dewpoint  humidity  cloud  \
# 319   320    1018.9     19.2         20.9     19.2      19.4      78.0   38.0
# 1051  322    1016.8     19.3         21.6     19.4      15.8      70.0   83.0
#
#       sunshine  winddirection  windspeed  month  month_sin  month_cos  \
# 319        5.7           80.0       36.0     11       -0.5   0.866025
# 1051       0.0           50.0       33.2     11       -0.5   0.866025
#
#        day_sin   day_cos
# 319  -0.699458  0.714673
# 1051 -0.674444  0.738326

# %% [markdown]
# ### 気温>最高気温となっている列を欠損値とする

# %%
print(train_x[(train_x['temparature'] > train_x['maxtemp'])])
train_x.loc[train_x['maxtemp'] < train_x['temparature'], 'maxtemp'] = np.nan
test_x.loc[test_x['maxtemp'] < test_x['temparature'], 'maxtemp'] = np.nan

print(f"\n欠損値の個数:{train_x['maxtemp'].isnull().sum()}")
# Out:
#       day  pressure  maxtemp  temparature  mintemp  dewpoint  humidity  cloud  \
# 1       2    1019.5     16.2         16.9     15.8      15.4      95.0   91.0
# 12     13    1020.4     15.0         15.5     13.2      12.0      77.0   86.0
# 369     5    1022.4     12.1         13.8     11.2       2.7      75.0   68.0
# 398    34    1013.7     22.3         23.0     21.0      20.4      91.0   84.0
# 653   289    1016.6     26.2         26.8     23.2      20.4      79.0   69.0
# 702   338    1021.1     17.3         18.0     16.1      16.1      70.0   86.0
# 734     5    1024.4     11.3         11.4     10.4       8.6      77.0   88.0
# 796    67    1020.6     18.8         19.9     17.1      16.0      79.0   95.0
# 1088  359    1025.9     17.5         18.0     16.5      13.3      79.0   89.0
# 1104   10    1022.3     15.2         15.8     13.5      11.1      78.0   94.0
# 1142   48    1013.3     17.1         17.2     15.2      14.8      87.0   90.0
# 1146   52    1016.7     17.4         17.6     16.4      16.3      96.0  100.0
# 1149   55    1022.3     17.5         18.2     16.9      14.3      92.0   96.0
# 1455  361    1016.4     16.3         16.6     15.9      15.0      91.0   96.0
# 1480   21    1020.1     13.3         14.4     11.6      10.5      89.0   85.0
# 1529   70    1020.3     18.5         19.2     17.7      13.3      60.0   38.0
# 1815  356    1024.0     20.3         20.5     17.8      14.5      77.0   86.0
# 1832    8    1017.8     17.2         17.9     16.0      15.7      98.0   93.0
# 2169  345    1016.3     16.3         16.5     15.8      16.6      91.0   83.0
# 2186  362    1012.4     17.2         17.3     16.3      15.3      91.0   88.0
#
#       sunshine  winddirection  windspeed  month     month_sin     month_cos  \
# 1          0.0           50.0       21.9      1  5.000000e-01  8.660254e-01
# 12         0.0           50.0       32.4      1  5.000000e-01  8.660254e-01
# 369        6.0           70.0       27.6      1  5.000000e-01  8.660254e-01
# 398        0.0           80.0       37.0      2  8.660254e-01  5.000000e-01
# 653        5.0           40.0       22.4     10 -8.660254e-01  5.000000e-01
# 702        3.0           40.0       14.8     12 -2.449294e-16  1.000000e+00
# 734        0.0           20.0       39.3      1  5.000000e-01  8.660254e-01
# 796        0.0           30.0       19.3      3  1.000000e+00  6.123234e-17
# 1088       0.5           20.0       23.4     12 -2.449294e-16  1.000000e+00
# 1104       0.0           60.0       37.0      1  5.000000e-01  8.660254e-01
# 1142       0.2           20.0       25.1      2  8.660254e-01  5.000000e-01
# 1146       0.2           50.0       16.1      2  8.660254e-01  5.000000e-01
# 1149       0.0           40.0       19.0      2  8.660254e-01  5.000000e-01
# 1455       0.0           70.0       37.0     12 -2.449294e-16  1.000000e+00
# 1480       1.9           20.0        9.9      1  5.000000e-01  8.660254e-01
# 1529       9.3           60.0        8.5      3  1.000000e+00  6.123234e-17
# 1815       0.0           60.0       34.3     12 -2.449294e-16  1.000000e+00
# 1832       0.0           40.0       59.5      1  5.000000e-01  8.660254e-01
# 2169       0.3           50.0       29.8     12 -2.449294e-16  1.000000e+00
# 2186       0.0           50.0       35.3     12 -2.449294e-16  1.000000e+00
#
#        day_sin   day_cos
# 1     0.034422  0.999407
# 12    0.221922  0.975065
# 369   0.085965  0.996298
# 398   0.552435  0.833556
# 653  -0.965740  0.259512
# 702  -0.448229  0.893919
# 734   0.085965  0.996298
# 796   0.914128  0.405426
# 1088 -0.103102  0.994671
# 1104  0.171293  0.985220
# 1142  0.735417  0.677615
# 1146  0.780296  0.625411
# 1149  0.811539  0.584298
# 1455 -0.068802  0.997630
# 1480  0.353676  0.935368
# 1529  0.933837  0.357698
# 1815 -0.154309  0.988023
# 1832  0.137279  0.990532
# 2169 -0.337523  0.941317
# 2186 -0.051620  0.998667
#
# 欠損値の個数:22

# %% [markdown]
# ### 気温差

# %%
train_x['df_temp'] = train_x['maxtemp'] - train_x['mintemp']
test_x['df_temp'] = test_x['maxtemp'] - test_x['mintemp']

print(train_x[['maxtemp','mintemp','df_temp']])
# Out:
#       maxtemp  mintemp  df_temp
# 0        21.2     19.9      1.3
# 1         NaN     15.8      NaN
# 2        19.4     14.6      4.8
# 3        18.1     16.9      1.2
# 4        21.3     15.2      6.1
# ...       ...      ...      ...
# 2185     23.2     19.1      4.1
# 2186      NaN     16.3      NaN
# 2187     19.0     14.3      4.7
# 2188     16.4     13.8      2.6
# 2189     21.2     18.0      3.2
#
# [2190 rows x 3 columns]

# %% [markdown]
# ### 露点温度

# %%
"""
import numpy as np

# 露点温度を計算する関数
def calculate_dew_point(temp, humidity):
    return temp - ((100 - humidity) / 5) * (1 + 0.01 * temp)

# train_x['maxtemp']が欠損値の場合、train_x['temperature']を使用
train_x['dew_point'] = np.where(
    train_x['maxtemp'].isnull(),
    calculate_dew_point(train_x['temparature'], train_x['humidity']),
    calculate_dew_point(train_x['maxtemp'], train_x['humidity'])
)

# 露点温度の結果を確認
print(train_x[['maxtemp', 'temparature', 'humidity', 'dew_point']].head())
"""
# Out:
# "\nimport numpy as np\n\n# 露点温度を計算する関数\ndef calculate_dew_point(temp, humidity):\n    return temp - ((100 - humidity) / 5) * (1 + 0.01 * temp)\n\n# train_x['maxtemp']が欠損値の場合、train_x['temperature']を使用\ntrain_x['dew_point'] = np.where(\n    train_x['maxtemp'].isnull(),\n    calculate_dew_point(train_x['temparature'], train_x['humidity']),\n    calculate_dew_point(train_x['maxtemp'], train_x['humidity'])\n)\n\n# 露点温度の結果を確認\nprint(train_x[['maxtemp', 'temparature', 'humidity', 'dew_point']].head())\n"

# %%
train_x
# Out:
#       day  pressure  maxtemp  temparature  mintemp  dewpoint  humidity  cloud  \
# 0       1    1017.4     21.2         20.6     19.9      19.4      87.0   88.0
# 1       2    1019.5      NaN         16.9     15.8      15.4      95.0   91.0
# 2       3    1024.1     19.4         16.1     14.6       9.3      75.0   47.0
# 3       4    1013.4     18.1         17.8     16.9      16.8      95.0   95.0
# 4       5    1021.8     21.3         18.4     15.2       9.6      52.0   45.0
# ...   ...       ...      ...          ...      ...       ...       ...    ...
# 2185  361    1014.6     23.2         20.6     19.1      19.9      97.0   88.0
# 2186  362    1012.4      NaN         17.3     16.3      15.3      91.0   88.0
# 2187  363    1013.3     19.0         16.3     14.3      12.6      79.0   79.0
# 2188  364    1022.3     16.4         15.2     13.8      14.7      92.0   93.0
# 2189  365    1013.8     21.2         19.1     18.0      18.0      89.0   88.0
#
#       sunshine  winddirection  windspeed  month     month_sin  month_cos  \
# 0          1.1           60.0       17.2      1  5.000000e-01   0.866025
# 1          0.0           50.0       21.9      1  5.000000e-01   0.866025
# 2          8.3           70.0       18.1      1  5.000000e-01   0.866025
# 3          0.0           60.0       35.6      1  5.000000e-01   0.866025
# 4          3.6           40.0       24.8      1  5.000000e-01   0.866025
# ...        ...            ...        ...    ...           ...        ...
# 2185       0.1           40.0       22.1     12 -2.449294e-16   1.000000
# 2186       0.0           50.0       35.3     12 -2.449294e-16   1.000000
# 2187       5.0           40.0       32.9     12 -2.449294e-16   1.000000
# 2188       0.1           40.0       18.0     12 -2.449294e-16   1.000000
# 2189       1.0           70.0       48.0     12 -2.449294e-16   1.000000
#
#            day_sin   day_cos  df_temp
# 0     1.721336e-02  0.999852      1.3
# 1     3.442161e-02  0.999407      NaN
# 2     5.161967e-02  0.998667      4.8
# 3     6.880243e-02  0.997630      1.2
# 4     8.596480e-02  0.996298      6.1
# ...            ...       ...      ...
# 2185 -6.880243e-02  0.997630      4.1
# 2186 -5.161967e-02  0.998667      NaN
# 2187 -3.442161e-02  0.999407      4.7
# 2188 -1.721336e-02  0.999852      2.6
# 2189  6.432491e-16  1.000000      3.2
#
# [2190 rows x 17 columns]

# %% [markdown]
# ### 最低温度<露点温度

# %%
train_x['mintemp_dewpoint'] = train_x['mintemp'] < train_x['dewpoint']
train_x['mintemp_dewpoint'] = train_x['mintemp_dewpoint'].astype(int)

test_x['mintemp_dewpoint'] = test_x['mintemp'] < test_x['dewpoint']
test_x['mintemp_dewpoint'] = test_x['mintemp_dewpoint'].astype(int)


# 結果を確認
print(train_x[['mintemp','dewpoint', 'mintemp_dewpoint']].head())
print(train_x[train_x['mintemp_dewpoint']==1])
# Out:
#    mintemp  dewpoint  mintemp_dewpoint
# 0     19.9      19.4                 0
# 1     15.8      15.4                 0
# 2     14.6       9.3                 0
# 3     16.9      16.8                 0
# 4     15.2       9.6                 0
#       day  pressure  maxtemp  temparature  mintemp  dewpoint  humidity  cloud  \
# 13     14    1012.5     13.5         12.9     11.6      11.8      87.0   92.0
# 15     16    1024.3     15.3         12.9     10.0      11.2      79.0   91.0
# 23     24    1013.0     24.8         19.9     17.1      18.1      90.0   92.0
# 24     25    1012.5     23.8         22.2     20.4      20.8      84.0   88.0
# 38     39    1023.1     20.4         17.8     14.8      15.0      75.0   43.0
# ...   ...       ...      ...          ...      ...       ...       ...    ...
# 2169  345    1016.3      NaN         16.5     15.8      16.6      91.0   83.0
# 2170  346    1024.1     19.3         18.3     17.3      18.8      77.0   84.0
# 2184  360    1015.8     20.9         18.8     17.6      17.7      78.0   88.0
# 2185  361    1014.6     23.2         20.6     19.1      19.9      97.0   88.0
# 2188  364    1022.3     16.4         15.2     13.8      14.7      92.0   93.0
#
#       sunshine  winddirection  windspeed  month     month_sin  month_cos  \
# 13         0.0           50.0       37.0      1  5.000000e-01   0.866025
# 15         0.3           20.0       20.0      1  5.000000e-01   0.866025
# 23         0.0           70.0       30.4      1  5.000000e-01   0.866025
# 24         0.0           70.0       30.2      1  5.000000e-01   0.866025
# 38         9.2           60.0       11.9      2  8.660254e-01   0.500000
# ...        ...            ...        ...    ...           ...        ...
# 2169       0.3           50.0       29.8     12 -2.449294e-16   1.000000
# 2170       8.3           80.0       31.8     12 -2.449294e-16   1.000000
# 2184       0.0           20.0       30.6     12 -2.449294e-16   1.000000
# 2185       0.1           40.0       22.1     12 -2.449294e-16   1.000000
# 2188       0.1           40.0       18.0     12 -2.449294e-16   1.000000
#
#        day_sin   day_cos  df_temp  mintemp_dewpoint
# 13    0.238673  0.971100      1.9                 1
# 15    0.271958  0.962309      5.3                 1
# 23    0.401488  0.915864      7.7                 1
# 24    0.417194  0.908818      3.4                 1
# 38    0.622047  0.782980      5.6                 1
# ...        ...       ...      ...               ...
# 2169 -0.337523  0.941317      NaN                 1
# 2170 -0.321270  0.946988      2.0                 1
# 2184 -0.085965  0.996298      3.3                 1
# 2185 -0.068802  0.997630      4.1                 1
# 2188 -0.017213  0.999852      2.6                 1
#
# [261 rows x 18 columns]

# %% [markdown]
# ### 気温ー露点温度の関係

# %%
#湿度が高いと降水の可能性が高まる
train_x['temp_dewpoint_diff'] = train_x['temparature'] - train_x['dewpoint']
test_x['temp_dewpoint_diff'] = test_x['temparature'] - test_x['dewpoint']
print(train_x["temp_dewpoint_diff"])
# Out:
# 0       1.2
# 1       1.5
# 2       6.8
# 3       1.0
# 4       8.8
#        ...
# 2185    0.7
# 2186    2.0
# 2187    3.7
# 2188    0.5
# 2189    1.1
# Name: temp_dewpoint_diff, Length: 2190, dtype: float64

# %% [markdown]
# ### 湿度*気圧の関係

# %%
#高湿度と低気圧が組み合わさると、降水の確率が高まる
train_x['humidity_pressure_interaction'] = train_x['humidity'] * train_x['pressure']
test_x['humidity_pressure_interaction'] = test_x['humidity'] * test_x['pressure']
print(train_x['humidity_pressure_interaction'])
# Out:
# 0       88513.8
# 1       96852.5
# 2       76807.5
# 3       96273.0
# 4       53133.6
#          ...
# 2185    98416.2
# 2186    92128.4
# 2187    80050.7
# 2188    94051.6
# 2189    90228.2
# Name: humidity_pressure_interaction, Length: 2190, dtype: float64

# %% [markdown]
# ### 風速 * 風向きの関係

# %%
#風速が高いときに降水が発生しやすい場
train_x['wind_direction_speed'] = train_x['winddirection'] * train_x['windspeed']
test_x['wind_direction_speed'] = test_x['winddirection'] * test_x['windspeed']
print(train_x['wind_direction_speed'])
# Out:
# 0       1032.0
# 1       1095.0
# 2       1267.0
# 3       2136.0
# 4        992.0
#          ...
# 2185     884.0
# 2186    1765.0
# 2187    1316.0
# 2188     720.0
# 2189    3360.0
# Name: wind_direction_speed, Length: 2190, dtype: float64

# %% [markdown]
# ### 月と日付の周期的な特徴量

# %%
#月ごとの温度差や、日ごとの温度変化を考慮した特徴量
train_x['month_day_interaction'] = train_x['month_sin'] * train_x['day_sin']
test_x['month_day_interaction'] = test_x['month_sin'] * test_x['day_sin']
print(train_x['month_day_interaction'])
# Out:
# 0       8.606678e-03
# 1       1.721081e-02
# 2       2.580983e-02
# 3       3.440121e-02
# 4       4.298240e-02
#             ...
# 2185    1.685173e-17
# 2186    1.264317e-17
# 2187    8.430863e-18
# 2188    4.216056e-18
# 2189   -1.575506e-31
# Name: month_day_interaction, Length: 2190, dtype: float64

# %% [markdown]
# ### 風速*日照時間

# %%
#強い風と日照時間が長いと、乾燥した天気が続きやすい
train_x['windspeed_sunshine_interaction'] = train_x['windspeed'] * train_x['sunshine']
test_x['windspeed_sunshine_interaction'] = test_x['windspeed'] * test_x['sunshine']
print(train_x['windspeed_sunshine_interaction'])
# Out:
# 0        18.92
# 1         0.00
# 2       150.23
# 3         0.00
# 4        89.28
#          ...
# 2185      2.21
# 2186      0.00
# 2187    164.50
# 2188      1.80
# 2189     48.00
# Name: windspeed_sunshine_interaction, Length: 2190, dtype: float64

# %% [markdown]
# ### 気温*湿度の関係

# %%
#気温と湿度が一緒に高い場合、降水の可能性が高い
train_x['temperature_humidity_interaction'] = train_x['temparature'] * train_x['humidity']
test_x['temperature_humidity_interaction'] = test_x['temparature'] * test_x['humidity']
print(train_x['temperature_humidity_interaction'])
# Out:
# 0       1792.2
# 1       1605.5
# 2       1207.5
# 3       1691.0
# 4        956.8
#          ...
# 2185    1998.2
# 2186    1574.3
# 2187    1287.7
# 2188    1398.4
# 2189    1699.9
# Name: temperature_humidity_interaction, Length: 2190, dtype: float64

# %% [markdown]
# ### 気温と日照時間の関係

# %%
#高い気温と長い日照時間が同時に発生すると、特定の気象条件が発生しやすい
train_x['temperature_sunshine_interaction'] = train_x['temparature'] * train_x['sunshine']
test_x['temperature_sunshine_interaction'] = test_x['temparature'] * test_x['sunshine']
print(train_x['temperature_sunshine_interaction'])
# Out:
# 0        22.66
# 1         0.00
# 2       133.63
# 3         0.00
# 4        66.24
#          ...
# 2185      2.06
# 2186      0.00
# 2187     81.50
# 2188      1.52
# 2189     19.10
# Name: temperature_sunshine_interaction, Length: 2190, dtype: float64

# %% [markdown]
# ### 気温と気圧の関係

# %%
#気圧が低いときに、暖かい空気が湿った状態であることが多い場合があります。
train_x['temperature_pressure_interaction'] = train_x['temparature'] * train_x['pressure']
test_x['temperature_pressure_interaction'] = test_x['temparature'] * test_x['pressure']
print(train_x['temperature_pressure_interaction'])
# Out:
# 0       20958.44
# 1       17229.55
# 2       16488.01
# 3       18038.52
# 4       18801.12
#           ...
# 2185    20900.76
# 2186    17514.52
# 2187    16516.79
# 2188    15538.96
# 2189    19363.58
# Name: temperature_pressure_interaction, Length: 2190, dtype: float64

# %% [markdown]
# ### 風速と湿度の関係

# %%
train_x['windspeed_humidity_interaction'] = train_x['windspeed'] * train_x['humidity']
test_x['windspeed_humidity_interaction'] = test_x['windspeed'] * test_x['humidity']
print(train_x['windspeed_humidity_interaction'])
# Out:
# 0       1496.4
# 1       2080.5
# 2       1357.5
# 3       3382.0
# 4       1289.6
#          ...
# 2185    2143.7
# 2186    3212.3
# 2187    2599.1
# 2188    1656.0
# 2189    4272.0
# Name: windspeed_humidity_interaction, Length: 2190, dtype: float64

# %% [markdown]
# ### 平均風速と気圧の関係

# %%
#強い風と低気圧が降水に関連する場合
train_x['pressure_windspeed_interaction'] = train_x['pressure'] * train_x['windspeed']
test_x['pressure_windspeed_interaction'] = test_x['pressure'] * test_x['windspeed']
print(train_x['pressure_windspeed_interaction'])
# Out:
# 0       17499.28
# 1       22327.05
# 2       18536.21
# 3       36077.04
# 4       25340.64
#           ...
# 2185    22422.66
# 2186    35737.72
# 2187    33337.57
# 2188    18401.40
# 2189    48662.40
# Name: pressure_windspeed_interaction, Length: 2190, dtype: float64

# %% [markdown]
# ### 湿度と雲量の関係

# %%
#高湿度と多くの雲が同時に存在すると、降水が発生する
train_x['humidity_cloud_interaction'] = train_x['humidity'] * train_x['cloud']
test_x['humidity_cloud_interaction'] = test_x['humidity'] * test_x['cloud']
print(train_x['humidity_cloud_interaction'])
# Out:
# 0       7656.0
# 1       8645.0
# 2       3525.0
# 3       9025.0
# 4       2340.0
#          ...
# 2185    8536.0
# 2186    8008.0
# 2187    6241.0
# 2188    8556.0
# 2189    7832.0
# Name: humidity_cloud_interaction, Length: 2190, dtype: float64

# %% [markdown]
# ### 湿度と露点温度の比率

# %%
#湿度が100%に近い場合、露点温度と気温が非常に近くなる
train_x['humidity_dewpoint_ratio'] = train_x['humidity'] / (train_x['dewpoint'] + 1)
test_x['humidity_dewpoint_ratio'] = test_x['humidity'] / (test_x['dewpoint'] + 1)
print(train_x['humidity_dewpoint_ratio'])
# Out:
# 0       4.264706
# 1       5.792683
# 2       7.281553
# 3       5.337079
# 4       4.905660
#           ...
# 2185    4.641148
# 2186    5.582822
# 2187    5.808824
# 2188    5.859873
# 2189    4.684211
# Name: humidity_dewpoint_ratio, Length: 2190, dtype: float64

# %% [markdown]
# ### 湿度と日照時間の関係

# %%
train_x['humidity_sunshine_interaction'] = train_x['humidity'] * train_x['sunshine']
test_x['humidity_sunshine_interaction'] = test_x['humidity'] * test_x['sunshine']
print(train_x['humidity_sunshine_interaction'])
# Out:
# 0        95.7
# 1         0.0
# 2       622.5
# 3         0.0
# 4       187.2
#         ...
# 2185      9.7
# 2186      0.0
# 2187    395.0
# 2188      9.2
# 2189     89.0
# Name: humidity_sunshine_interaction, Length: 2190, dtype: float64

# %% [markdown]
# ### 気温の推移

# %%
train_x['temp_change'] = train_x['temparature'] - train_x['temparature'].shift(1)
test_x['temp_change'] = test_x['temparature'] - test_x['temparature'].shift(1)
print(train_x['temp_change'])
# Out:
# 0       NaN
# 1      -3.7
# 2      -0.8
# 3       1.7
# 4       0.6
#        ...
# 2185    1.8
# 2186   -3.3
# 2187   -1.0
# 2188   -1.1
# 2189    3.9
# Name: temp_change, Length: 2190, dtype: float64

# %% [markdown]
# ### 気圧の変化率

# %%
#急激な気圧の変化は天気の変化、特に降水の発生と関係しています
train_x['pressure_change_rate'] = train_x['pressure'] - train_x['pressure'].shift(1)
test_x['pressure_change_rate'] = test_x['pressure'] - test_x['pressure'].shift(1)

# %% [markdown]
# ### 風速の変化

# %%
#風速の急激な変化が天候に与える影響を捉えます
train_x['windspeed_change'] = train_x['windspeed'] - train_x['windspeed'].shift(1)
test_x['windspeed_change'] = test_x['windspeed'] - test_x['windspeed'].shift(1)

# %% [markdown]
# ### 気温の週単位の変化

# %%
train_x['week_temperature_change'] = train_x['temparature'] - train_x['temparature'].shift(7)
test_x['week_temperature_change'] = test_x['temparature'] - test_x['temparature'].shift(7)

# %% [markdown]
# ### 風速の極端な変化

# %%
train_x['extreme_windspeed_change'] = (train_x['windspeed'] - train_x['windspeed'].shift(1)).abs() > 5
train_x['extreme_windspeed_change'] = train_x['extreme_windspeed_change'].astype(int)

test_x['extreme_windspeed_change'] = (test_x['windspeed'] - test_x['windspeed'].shift(1)).abs() > 5
test_x['extreme_windspeed_change'] = test_x['extreme_windspeed_change'].astype(int)

# %% [markdown]
# ### 日付と降水確率

# %%
train_x['day_of_week'] = train_x['day'] % 7
test_x['day_of_week'] = test_x['day'] % 7

# %%
train_x
# Out:
#       day  pressure  maxtemp  temparature  mintemp  dewpoint  humidity  cloud  \
# 0       1    1017.4     21.2         20.6     19.9      19.4      87.0   88.0
# 1       2    1019.5      NaN         16.9     15.8      15.4      95.0   91.0
# 2       3    1024.1     19.4         16.1     14.6       9.3      75.0   47.0
# 3       4    1013.4     18.1         17.8     16.9      16.8      95.0   95.0
# 4       5    1021.8     21.3         18.4     15.2       9.6      52.0   45.0
# ...   ...       ...      ...          ...      ...       ...       ...    ...
# 2185  361    1014.6     23.2         20.6     19.1      19.9      97.0   88.0
# 2186  362    1012.4      NaN         17.3     16.3      15.3      91.0   88.0
# 2187  363    1013.3     19.0         16.3     14.3      12.6      79.0   79.0
# 2188  364    1022.3     16.4         15.2     13.8      14.7      92.0   93.0
# 2189  365    1013.8     21.2         19.1     18.0      18.0      89.0   88.0
#
#       sunshine  winddirection  ...  pressure_windspeed_interaction  \
# 0          1.1           60.0  ...                        17499.28
# 1          0.0           50.0  ...                        22327.05
# 2          8.3           70.0  ...                        18536.21
# 3          0.0           60.0  ...                        36077.04
# 4          3.6           40.0  ...                        25340.64
# ...        ...            ...  ...                             ...
# 2185       0.1           40.0  ...                        22422.66
# 2186       0.0           50.0  ...                        35737.72
# 2187       5.0           40.0  ...                        33337.57
# 2188       0.1           40.0  ...                        18401.40
# 2189       1.0           70.0  ...                        48662.40
#
#       humidity_cloud_interaction  humidity_dewpoint_ratio  \
# 0                         7656.0                 4.264706
# 1                         8645.0                 5.792683
# 2                         3525.0                 7.281553
# 3                         9025.0                 5.337079
# 4                         2340.0                 4.905660
# ...                          ...                      ...
# 2185                      8536.0                 4.641148
# 2186                      8008.0                 5.582822
# 2187                      6241.0                 5.808824
# 2188                      8556.0                 5.859873
# 2189                      7832.0                 4.684211
#
#       humidity_sunshine_interaction  temp_change  pressure_change_rate  \
# 0                              95.7          NaN                   NaN
# 1                               0.0         -3.7                   2.1
# 2                             622.5         -0.8                   4.6
# 3                               0.0          1.7                 -10.7
# 4                             187.2          0.6                   8.4
# ...                             ...          ...                   ...
# 2185                            9.7          1.8                  -1.2
# 2186                            0.0         -3.3                  -2.2
# 2187                          395.0         -1.0                   0.9
# 2188                            9.2         -1.1                   9.0
# 2189                           89.0          3.9                  -8.5
#
#       windspeed_change  week_temperature_change  extreme_windspeed_change  \
# 0                  NaN                      NaN                         0
# 1                  4.7                      NaN                         0
# 2                 -3.8                      NaN                         0
# 3                 17.5                      NaN                         1
# 4                -10.8                      NaN                         1
# ...                ...                      ...                       ...
# 2185              -8.5                      0.1                         1
# 2186              13.2                     -1.6                         1
# 2187              -2.4                     -4.5                         0
# 2188             -14.9                     -5.6                         1
# 2189              30.0                      2.3                         1
#
#       day_of_week
# 0               1
# 1               2
# 2               3
# 3               4
# 4               5
# ...           ...
# 2185            4
# 2186            5
# 2187            6
# 2188            0
# 2189            1
#
# [2190 rows x 37 columns]

# %%
#変数を削除する
#train_x = train_x.drop(['day'],axis=1)
#test_x = test_x.drop(['day'],axis=1)

# %%
# 特徴量同士の内容が一致するかを比較
duplicates = []
for col1 in train_x.columns:
    for col2 in train_x.columns:
        if col1 != col2 and col1 not in duplicates and col2 not in duplicates:
            if train_x[col1].equals(train_x[col2]):
                duplicates.append(col1)
                duplicates.append(col2)

print("同じ内容の特徴量:", duplicates)
# Out:
# 同じ内容の特徴量: []

# %% [markdown]
# ## モデルの作成

# %%
#"""
import optuna
import numpy as np
import xgboost as xgb
from sklearn.model_selection import train_test_split, cross_val_score
from sklearn.metrics import log_loss

# ランダムシードを設定
np.random.seed(71)  # NumPyの乱数シード
import random
random.seed(71)  # Pythonのランダムシード

# 目的関数（評価指標: log_loss）
def objective(trial):
    params = {
        'max_depth': trial.suggest_int('max_depth', 2, 15),
        'min_child_weight': trial.suggest_int('min_child_weight', 1, 20),
        'learning_rate': trial.suggest_float('learning_rate', 0.001, 0.5),
        'subsample': trial.suggest_float('subsample', 0.3, 1.0),
        'colsample_bytree': trial.suggest_float('colsample_bytree', 0.3, 1.0),
        'n_estimators': trial.suggest_int('n_estimators', 50, 2000),
        'gamma': trial.suggest_float('gamma', 0, 20),
        'reg_alpha': trial.suggest_float('reg_alpha', 0, 20),
        'reg_lambda': trial.suggest_float('reg_lambda', 0, 20),
        'random_state': 71,
        'use_label_encoder': False,
        'eval_metric': 'logloss'
    }

    # モデルの定義
    model = xgb.XGBClassifier(**params, n_jobs=-1)

    # 5分割クロスバリデーションで評価
    score = cross_val_score(model, train_x, train_y, scoring='neg_log_loss', cv=5, n_jobs=-1)
    
    return -1.0 * np.mean(score)  # log_loss は小さい方が良いので符号を反転

# Optuna でベイズ最適化
study = optuna.create_study(direction='minimize')
study.optimize(objective, n_trials=1000)  # 試行回数を500に増加

# 最適なパラメータ
best_params = study.best_params
print(f'最適なパラメータ: {best_params}')
#"""
# Out:
# [I 2025-03-04 01:22:11,606] A new study created in memory with name: no-name-d6c8060b-aa55-4c5d-b5f6-d4b72dd93e64
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:12] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:12] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:12] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:12] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:12] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-04 01:22:12,439] Trial 0 finished with value: 0.3605558971929118 and parameters: {'max_depth': 12, 'min_child_weight': 1, 'learning_rate': 0.04946209623008108, 'subsample': 0.8315038780429651, 'colsample_bytree': 0.30021753543907315, 'n_estimators': 59, 'gamma': 1.9087417828388231, 'reg_alpha': 12.503049613808097, 'reg_lambda': 10.321518535282994}. Best is trial 0 with value: 0.3605558971929118.
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:12] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:12] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:12] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:12] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:12] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-04 01:22:12,844] Trial 1 finished with value: 0.4002147415694455 and parameters: {'max_depth': 2, 'min_child_weight': 15, 'learning_rate': 0.019598272031626694, 'subsample': 0.7918416797167864, 'colsample_bytree': 0.32289944363760265, 'n_estimators': 79, 'gamma': 13.68291701634983, 'reg_alpha': 12.919403054982528, 'reg_lambda': 19.985831411772608}. Best is trial 0 with value: 0.3605558971929118.
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:12] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:12] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:12] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:13] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:13] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-04 01:22:13,320] Trial 2 finished with value: 0.3554055020266298 and parameters: {'max_depth': 8, 'min_child_weight': 6, 'learning_rate': 0.49539449324645746, 'subsample': 0.35159490864978166, 'colsample_bytree': 0.6109651283408278, 'n_estimators': 381, 'gamma': 7.162823195957424, 'reg_alpha': 5.460805893753271, 'reg_lambda': 14.362162569815018}. Best is trial 2 with value: 0.3554055020266298.
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:13] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:13] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:13] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:13] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:13] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-04 01:22:13,747] Trial 3 finished with value: 0.3736879704465685 and parameters: {'max_depth': 9, 'min_child_weight': 16, 'learning_rate': 0.036086491607060824, 'subsample': 0.7683696656612691, 'colsample_bytree': 0.4634570762787495, 'n_estimators': 234, 'gamma': 19.291010855902524, 'reg_alpha': 17.574768560487716, 'reg_lambda': 5.729531765334437}. Best is trial 2 with value: 0.3554055020266298.
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:13] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:13] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:13] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:13] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:14] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-04 01:22:14,199] Trial 4 finished with value: 0.37800229120195394 and parameters: {'max_depth': 15, 'min_child_weight': 13, 'learning_rate': 0.25416219498231385, 'subsample': 0.4612177913205761, 'colsample_bytree': 0.4276448443328495, 'n_estimators': 629, 'gamma': 13.4150263724197, 'reg_alpha': 19.884856688808142, 'reg_lambda': 17.43406661534799}. Best is trial 2 with value: 0.3554055020266298.
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:14] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:14] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:14] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:14] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:14] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-04 01:22:14,847] Trial 5 finished with value: 0.34876763507633696 and parameters: {'max_depth': 13, 'min_child_weight': 13, 'learning_rate': 0.2503394995819942, 'subsample': 0.7942387389588975, 'colsample_bytree': 0.9016391505236464, 'n_estimators': 1647, 'gamma': 5.699123889910758, 'reg_alpha': 7.918568304959555, 'reg_lambda': 14.04971939576379}. Best is trial 5 with value: 0.34876763507633696.
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:14] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:14] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:14] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:14] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:14] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-04 01:22:14,924] Trial 6 finished with value: 0.3606149460568388 and parameters: {'max_depth': 3, 'min_child_weight': 16, 'learning_rate': 0.018643612300567484, 'subsample': 0.5558250988047594, 'colsample_bytree': 0.6354991381751943, 'n_estimators': 245, 'gamma': 3.5795233706728324, 'reg_alpha': 12.259588500149277, 'reg_lambda': 16.550173830748818}. Best is trial 5 with value: 0.34876763507633696.
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:14] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:14] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:14] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:14] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:14] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-04 01:22:15,170] Trial 7 finished with value: 0.3583878018366847 and parameters: {'max_depth': 6, 'min_child_weight': 16, 'learning_rate': 0.10355782860523764, 'subsample': 0.8466350021799581, 'colsample_bytree': 0.9609974170731694, 'n_estimators': 1461, 'gamma': 12.797982574113222, 'reg_alpha': 11.945069069595409, 'reg_lambda': 2.043952708126444}. Best is trial 5 with value: 0.34876763507633696.
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:15] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:15] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:15] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:15] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:15] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-04 01:22:15,411] Trial 8 finished with value: 0.3590934141651706 and parameters: {'max_depth': 15, 'min_child_weight': 1, 'learning_rate': 0.3954414776662439, 'subsample': 0.5951573802738797, 'colsample_bytree': 0.33490323302286723, 'n_estimators': 1742, 'gamma': 10.850283324024147, 'reg_alpha': 8.249541374604231, 'reg_lambda': 15.32160307477862}. Best is trial 5 with value: 0.34876763507633696.
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:15] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:15] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:15] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:15] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:15] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-04 01:22:15,587] Trial 9 finished with value: 0.3552043925703784 and parameters: {'max_depth': 12, 'min_child_weight': 13, 'learning_rate': 0.3504153530129856, 'subsample': 0.8710421199410415, 'colsample_bytree': 0.6583416006385748, 'n_estimators': 1054, 'gamma': 16.860356341173418, 'reg_alpha': 8.357119281502817, 'reg_lambda': 3.7867005128537756}. Best is trial 5 with value: 0.34876763507633696.
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:15] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:15] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:15] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:15] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:15] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-04 01:22:15,914] Trial 10 finished with value: 0.34706313340431016 and parameters: {'max_depth': 12, 'min_child_weight': 20, 'learning_rate': 0.18945735526191282, 'subsample': 0.6859538087474871, 'colsample_bytree': 0.9402388395937868, 'n_estimators': 1978, 'gamma': 7.370996044291214, 'reg_alpha': 0.1300433024997094, 'reg_lambda': 10.399005750425863}. Best is trial 10 with value: 0.34706313340431016.
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:15] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:15] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:15] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:15] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:15] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-04 01:22:16,231] Trial 11 finished with value: 0.34443772707461234 and parameters: {'max_depth': 12, 'min_child_weight': 19, 'learning_rate': 0.1833333724289761, 'subsample': 0.9956514859342497, 'colsample_bytree': 0.9877489322570884, 'n_estimators': 1941, 'gamma': 6.082772591000774, 'reg_alpha': 1.158676440885027, 'reg_lambda': 10.054572050066064}. Best is trial 11 with value: 0.34443772707461234.
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:16] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:16] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:16] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:16] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:16] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-04 01:22:16,528] Trial 12 finished with value: 0.344168172894119 and parameters: {'max_depth': 10, 'min_child_weight': 20, 'learning_rate': 0.18522557670556056, 'subsample': 0.9939616882695097, 'colsample_bytree': 0.8356469700211695, 'n_estimators': 1959, 'gamma': 7.553092018628342, 'reg_alpha': 0.40103449338838426, 'reg_lambda': 9.938961941315647}. Best is trial 12 with value: 0.344168172894119.
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:16] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:16] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:16] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:16] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:16] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-04 01:22:16,736] Trial 13 finished with value: 0.345378771059799 and parameters: {'max_depth': 9, 'min_child_weight': 20, 'learning_rate': 0.16051442212882935, 'subsample': 0.9830818943961614, 'colsample_bytree': 0.8074085100751766, 'n_estimators': 1257, 'gamma': 9.435154689564934, 'reg_alpha': 0.03670280523888236, 'reg_lambda': 7.598799995503912}. Best is trial 12 with value: 0.344168172894119.
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:16] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:16] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:16] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:16] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:16] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-04 01:22:17,058] Trial 14 finished with value: 0.344336385921389 and parameters: {'max_depth': 10, 'min_child_weight': 8, 'learning_rate': 0.23586913140579405, 'subsample': 0.9956242281713669, 'colsample_bytree': 0.7735435358342322, 'n_estimators': 1982, 'gamma': 4.343206428737883, 'reg_alpha': 2.7788899435336436, 'reg_lambda': 11.701161513818182}. Best is trial 12 with value: 0.344168172894119.
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:17] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:17] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:17] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:17] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:17] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-04 01:22:17,353] Trial 15 finished with value: 0.3744833816827783 and parameters: {'max_depth': 5, 'min_child_weight': 8, 'learning_rate': 0.2769390372131389, 'subsample': 0.9451711368248501, 'colsample_bytree': 0.7798584462794308, 'n_estimators': 1532, 'gamma': 0.16649675814138032, 'reg_alpha': 3.7182590938294906, 'reg_lambda': 12.9653906060102}. Best is trial 12 with value: 0.344168172894119.
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:17] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:17] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:17] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:17] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:17] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-04 01:22:17,512] Trial 16 finished with value: 0.3425678887203244 and parameters: {'max_depth': 10, 'min_child_weight': 8, 'learning_rate': 0.31490782413866564, 'subsample': 0.9336239780666721, 'colsample_bytree': 0.7744001921838642, 'n_estimators': 783, 'gamma': 3.67596734385916, 'reg_alpha': 3.6320547652749964, 'reg_lambda': 7.591537341632277}. Best is trial 16 with value: 0.3425678887203244.
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:17] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:17] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:17] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:17] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:17] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-04 01:22:17,672] Trial 17 finished with value: 0.347359447381652 and parameters: {'max_depth': 7, 'min_child_weight': 6, 'learning_rate': 0.3597910454782005, 'subsample': 0.8987934313063043, 'colsample_bytree': 0.8545639215251375, 'n_estimators': 734, 'gamma': 8.971874677440052, 'reg_alpha': 4.998894320709258, 'reg_lambda': 7.570628828459638}. Best is trial 16 with value: 0.3425678887203244.
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:17] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:17] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:17] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:17] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:17] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-04 01:22:17,851] Trial 18 finished with value: 0.36840611195966705 and parameters: {'max_depth': 10, 'min_child_weight': 10, 'learning_rate': 0.31483271181618455, 'subsample': 0.715944727529197, 'colsample_bytree': 0.7059701985476363, 'n_estimators': 876, 'gamma': 2.793023908462629, 'reg_alpha': 2.3986956797902517, 'reg_lambda': 0.17813227852400715}. Best is trial 16 with value: 0.3425678887203244.
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:17] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:17] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:17] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:17] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:17] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-04 01:22:18,049] Trial 19 finished with value: 0.3708688966240151 and parameters: {'max_depth': 5, 'min_child_weight': 5, 'learning_rate': 0.45748427920420315, 'subsample': 0.9346478908222664, 'colsample_bytree': 0.5645034477854314, 'n_estimators': 1190, 'gamma': 0.13727246232207335, 'reg_alpha': 6.361655936541641, 'reg_lambda': 7.501380288118568}. Best is trial 16 with value: 0.3425678887203244.
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:18] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:18] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:18] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:18] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:18] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-04 01:22:18,177] Trial 20 finished with value: 0.3470914596497505 and parameters: {'max_depth': 10, 'min_child_weight': 4, 'learning_rate': 0.11530302355023685, 'subsample': 0.605193094655498, 'colsample_bytree': 0.7219306414789959, 'n_estimators': 550, 'gamma': 11.028576922478976, 'reg_alpha': 3.5687141849726842, 'reg_lambda': 4.759411548194421}. Best is trial 16 with value: 0.3425678887203244.
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:18] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:18] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:18] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:18] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:18] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-04 01:22:18,438] Trial 21 finished with value: 0.3442733453531306 and parameters: {'max_depth': 10, 'min_child_weight': 9, 'learning_rate': 0.21615373919977976, 'subsample': 0.9990892639508807, 'colsample_bytree': 0.7832842679920498, 'n_estimators': 1800, 'gamma': 4.2994218717480255, 'reg_alpha': 2.2757744508335946, 'reg_lambda': 12.247256448696687}. Best is trial 16 with value: 0.3425678887203244.
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:18] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:18] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:18] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:18] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:18] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-04 01:22:18,720] Trial 22 finished with value: 0.3421436980027718 and parameters: {'max_depth': 8, 'min_child_weight': 9, 'learning_rate': 0.2146978693739129, 'subsample': 0.8956490593239207, 'colsample_bytree': 0.8586226530254321, 'n_estimators': 1781, 'gamma': 4.4260542149502715, 'reg_alpha': 1.760175857899106, 'reg_lambda': 8.483698241646739}. Best is trial 22 with value: 0.3421436980027718.
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:18] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:18] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:18] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:18] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:18] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-04 01:22:18,940] Trial 23 finished with value: 0.3446664732950513 and parameters: {'max_depth': 8, 'min_child_weight': 12, 'learning_rate': 0.3027581749992458, 'subsample': 0.9099706610077456, 'colsample_bytree': 0.8663216504205149, 'n_estimators': 1370, 'gamma': 8.099080651174528, 'reg_alpha': 1.5065658695023274, 'reg_lambda': 8.548861879649582}. Best is trial 22 with value: 0.3421436980027718.
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:18] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:18] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:18] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:18] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:18] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-04 01:22:19,109] Trial 24 finished with value: 0.3435113869784364 and parameters: {'max_depth': 6, 'min_child_weight': 10, 'learning_rate': 0.10403743540085579, 'subsample': 0.8750754507435841, 'colsample_bytree': 0.8414600979294024, 'n_estimators': 907, 'gamma': 5.611611984798589, 'reg_alpha': 4.476756637257323, 'reg_lambda': 5.642629371608342}. Best is trial 22 with value: 0.3421436980027718.
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:19] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:19] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:19] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:19] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:19] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-04 01:22:19,302] Trial 25 finished with value: 0.3484824617163794 and parameters: {'max_depth': 6, 'min_child_weight': 11, 'learning_rate': 0.1172423097464316, 'subsample': 0.7321843450000523, 'colsample_bytree': 0.9096399843505076, 'n_estimators': 940, 'gamma': 1.511261564411531, 'reg_alpha': 4.709368746232484, 'reg_lambda': 6.311497932460501}. Best is trial 22 with value: 0.3421436980027718.
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:19] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:19] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:19] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:19] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:19] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-04 01:22:19,449] Trial 26 finished with value: 0.3454129213828243 and parameters: {'max_depth': 4, 'min_child_weight': 8, 'learning_rate': 0.08045375802470298, 'subsample': 0.8407081347566032, 'colsample_bytree': 0.699133957844198, 'n_estimators': 821, 'gamma': 5.459388943771367, 'reg_alpha': 6.545970054572066, 'reg_lambda': 3.511858929496812}. Best is trial 22 with value: 0.3421436980027718.
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:19] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:19] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:19] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:22:19] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
# ...
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:26:13] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:26:13] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:26:13] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:26:13] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:26:13] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-04 01:26:13,635] Trial 991 finished with value: 0.34239843732759667 and parameters: {'max_depth': 14, 'min_child_weight': 17, 'learning_rate': 0.4474004828042739, 'subsample': 0.999682117228134, 'colsample_bytree': 0.5739110998356463, 'n_estimators': 1587, 'gamma': 8.907698983748425, 'reg_alpha': 0.9445250110566605, 'reg_lambda': 0.9734246796816483}. Best is trial 892 with value: 0.33480676432979495.
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:26:13] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:26:13] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:26:13] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:26:13] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:26:13] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-04 01:26:13,918] Trial 992 finished with value: 0.34049084545347397 and parameters: {'max_depth': 15, 'min_child_weight': 15, 'learning_rate': 0.4799015032685115, 'subsample': 0.9447005452927398, 'colsample_bytree': 0.598054407500074, 'n_estimators': 1653, 'gamma': 8.065841670214425, 'reg_alpha': 1.6428650779487142, 'reg_lambda': 0.008227818350121843}. Best is trial 892 with value: 0.33480676432979495.
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:26:13] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:26:13] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:26:13] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:26:13] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:26:13] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-04 01:26:14,213] Trial 993 finished with value: 0.3410814936854417 and parameters: {'max_depth': 13, 'min_child_weight': 16, 'learning_rate': 0.43557545980731205, 'subsample': 0.9051390162632661, 'colsample_bytree': 0.6158392489148982, 'n_estimators': 1847, 'gamma': 8.615362325838424, 'reg_alpha': 0.6930929631539878, 'reg_lambda': 0.32931113513819543}. Best is trial 892 with value: 0.33480676432979495.
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:26:14] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:26:14] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:26:14] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:26:14] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:26:14] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-04 01:26:14,481] Trial 994 finished with value: 0.3402005144892775 and parameters: {'max_depth': 14, 'min_child_weight': 17, 'learning_rate': 0.4629131558351627, 'subsample': 0.9681971977645699, 'colsample_bytree': 0.5879330124992642, 'n_estimators': 1755, 'gamma': 7.710331490117529, 'reg_alpha': 0.3758257926926549, 'reg_lambda': 0.012584980327473405}. Best is trial 892 with value: 0.33480676432979495.
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:26:14] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:26:14] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:26:14] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:26:14] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:26:14] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-04 01:26:14,765] Trial 995 finished with value: 0.34867349063854186 and parameters: {'max_depth': 14, 'min_child_weight': 15, 'learning_rate': 0.4237877277691489, 'subsample': 0.6454884244211494, 'colsample_bytree': 0.5610258197327673, 'n_estimators': 1703, 'gamma': 9.397681646774673, 'reg_alpha': 1.3007211377756855, 'reg_lambda': 0.0028964921558897183}. Best is trial 892 with value: 0.33480676432979495.
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:26:14] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:26:14] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:26:14] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:26:14] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:26:14] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-04 01:26:15,062] Trial 996 finished with value: 0.33737264346787343 and parameters: {'max_depth': 13, 'min_child_weight': 14, 'learning_rate': 0.4547328780727845, 'subsample': 0.9520495097248675, 'colsample_bytree': 0.6314844055852175, 'n_estimators': 1794, 'gamma': 8.314654225523629, 'reg_alpha': 0.005509632452952218, 'reg_lambda': 0.665313443272687}. Best is trial 892 with value: 0.33480676432979495.
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:26:15] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:26:15] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:26:15] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:26:15] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:26:15] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-04 01:26:15,330] Trial 997 finished with value: 0.3407351313951382 and parameters: {'max_depth': 15, 'min_child_weight': 16, 'learning_rate': 0.4694714643644858, 'subsample': 0.9334057491638935, 'colsample_bytree': 0.5797665304547135, 'n_estimators': 1624, 'gamma': 8.957926706996448, 'reg_alpha': 2.433021444882721, 'reg_lambda': 1.1426073626456004}. Best is trial 892 with value: 0.33480676432979495.
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:26:15] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:26:15] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:26:15] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:26:15] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:26:15] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-04 01:26:15,624] Trial 998 finished with value: 0.3395405305010637 and parameters: {'max_depth': 14, 'min_child_weight': 16, 'learning_rate': 0.4377743703324183, 'subsample': 0.9723707809102584, 'colsample_bytree': 0.6056010190210893, 'n_estimators': 1880, 'gamma': 6.681451798949938, 'reg_alpha': 0.9208512346981298, 'reg_lambda': 0.38993175115122924}. Best is trial 892 with value: 0.33480676432979495.
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:26:15] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:26:15] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:26:15] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:26:15] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# /opt/homebrew/var/pyenv/versions/3.12.6/lib/python3.12/site-packages/xgboost/core.py:158: UserWarning: [01:26:15] WARNING: /Users/runner/work/xgboost/xgboost/src/learner.cc:740:
# Parameters: { "use_label_encoder" } are not used.
#
#   warnings.warn(smsg, UserWarning)
# [I 2025-03-04 01:26:15,898] Trial 999 finished with value: 0.34301405330619816 and parameters: {'max_depth': 14, 'min_child_weight': 10, 'learning_rate': 0.447738341845376, 'subsample': 0.9854944992115536, 'colsample_bytree': 0.5457604215376861, 'n_estimators': 1722, 'gamma': 9.917261784910258, 'reg_alpha': 1.8544557592772797, 'reg_lambda': 0.6611250179758544}. Best is trial 892 with value: 0.33480676432979495.
# 最適なパラメータ: {'max_depth': 14, 'min_child_weight': 16, 'learning_rate': 0.46293494630941656, 'subsample': 0.9543856586378973, 'colsample_bytree': 0.5704904495305176, 'n_estimators': 1829, 'gamma': 9.641354563635204, 'reg_alpha': 0.6577615127424661, 'reg_lambda': 0.010413379968255719}

# %%
#"""
from sklearn.metrics import accuracy_score, log_loss, precision_score, recall_score, f1_score, confusion_matrix

# モデルの作成と学習
model = xgb.XGBClassifier(**best_params, n_jobs=-1)
model.fit(train_x, train_y)

# テストデータで評価
y_pred_prob = model.predict_proba(train_x)  # 確率予測
logloss = log_loss(train_y, y_pred_prob)  # log_lossを計算

# 予測ラベルを取得
y_pred_label = model.predict(train_x)

# 正当率（accuracy）の計算
accuracy = accuracy_score(train_y, y_pred_label)

# その他の評価指標
precision = precision_score(train_y, y_pred_label, average='weighted')  # クラスごとに重み付き適合率
recall = recall_score(train_y, y_pred_label, average='weighted')  # クラスごとに重み付き再現率
f1 = f1_score(train_y, y_pred_label, average='weighted')  # クラスごとに重み付きF1スコア
conf_matrix = confusion_matrix(train_y, y_pred_label)  # 混同行列

# 結果を表示
print(f'Test Log Loss: {logloss:.4f}')
print(f'Test Accuracy: {accuracy:.4f}')
print(f'Test Precision: {precision:.4f}')
print(f'Test Recall: {recall:.4f}')
print(f'Test F1 Score: {f1:.4f}')
print(f'Confusion Matrix:\n{conf_matrix}')
#"""
# Out:
# Test Log Loss: 0.3155
# Test Accuracy: 0.8781
# Test Precision: 0.8744
# Test Recall: 0.8781
# Test F1 Score: 0.8750
# Confusion Matrix:
# [[ 370  170]
#  [  97 1553]]

# %%
# train_xの各列のデータ型を確認
print(train_x.dtypes)

# 数値に変換できない列を適切に処理
# 例えば、カテゴリカルな列をOneHotエンコーディングするなど
train_x = pd.get_dummies(train_x, drop_first=True)  # カテゴリカル変数をダミー変数に変換
# Out:
# day                                   int64
# pressure                            float64
# maxtemp                             float64
# temparature                         float64
# mintemp                             float64
# dewpoint                            float64
# humidity                            float64
# cloud                               float64
# sunshine                            float64
# winddirection                       float64
# windspeed                           float64
# month                                 int32
# month_sin                           float64
# month_cos                           float64
# day_sin                             float64
# day_cos                             float64
# df_temp                             float64
# mintemp_dewpoint                      int64
# temp_dewpoint_diff                  float64
# humidity_pressure_interaction       float64
# wind_direction_speed                float64
# month_day_interaction               float64
# windspeed_sunshine_interaction      float64
# temperature_humidity_interaction    float64
# temperature_sunshine_interaction    float64
# temperature_pressure_interaction    float64
# windspeed_humidity_interaction      float64
# pressure_windspeed_interaction      float64
# humidity_cloud_interaction          float64
# humidity_dewpoint_ratio             float64
# humidity_sunshine_interaction       float64
# temp_change                         float64
# pressure_change_rate                float64
# windspeed_change                    float64
# week_temperature_change             float64
# extreme_windspeed_change              int64
# day_of_week                           int64
# dtype: object

# %%
#""""
import shap
import matplotlib.pyplot as plt

# SHAPのExplainerを作成
explainer = shap.Explainer(model, train_x)

# SHAP値を計算
shap_values = explainer(train_x)

# 特徴量の重要度を可視化（サマリープロット）
shap.summary_plot(shap_values, train_x)

# 特定のサンプルについてSHAPの力価プロットを表示（例: 0番目のデータ）
shap.plots.waterfall(shap_values[0])
#"""

# %%
#"""
from sklearn.metrics import accuracy_score
model.fit(train_x, train_y)

# テストデータの予測確率を取得
pred_prob = model.predict_proba(test_x)[:, 1]

# 最適なしきい値を使用して予測値を二値に変換
#pred_label = np.where(pred_prob > best_threshold, 1, 0)
pred_label = np.where(pred_prob > 0.5, 1, 0)

# 提出用ファイルの作成
submission = pd.DataFrame({
    'id': test['id'], 
    'rainfall': pred_label
})

# 出力確認
print(submission)

# best['Survived']とpred_labelの1の数を比較
print("予測結果pred_labelの1の数:", pred_label.sum())
#"""
# Out:
#        id  rainfall
# 0    2190         1
# 1    2191         1
# 2    2192         1
# 3    2193         0
# 4    2194         0
# ..    ...       ...
# 725  2915         1
# 726  2916         1
# 727  2917         1
# 728  2918         1
# 729  2919         1
#
# [730 rows x 2 columns]
# 予測結果pred_labelの1の数: 572

# %%
# 提出用ファイルの保存（例: 'submission.csv'）
submission.to_csv('submit/submission_4.csv', index=False)
